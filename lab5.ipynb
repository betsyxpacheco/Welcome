# %% [markdown]
# <a href="https://colab.research.google.com/github/betsyxpacheco/Welcome/blob/main/lab5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IS 4487 Module 2 Script
#
# ## Agenda
#
# - Loading installed packages
# - Inspect data
# - Explore plot types
#
# Make sure you have downloaded tonight's script and data from Canvas.

# %% [markdown]
# ##Load Libraries
#
# In this class we will be using
# - Pandas
# - Scikitlearn
# - Matplotlib
#
# We can pull sample data from
# - statsmodels.api

# %%
import pandas as pd
import matplotlib as mpl
import sklearn as sl

# %% [markdown]
# ## Getting data into Pandas
#
# In this case we will load data from the statsmodels.org library
#
# See the Canvas assignments and lectures for a description of the Megatelco data
#
# **Note:** you will need to enter a code supplied by Google in the next step.

# %%
from google.colab import drive 
drive.mount('/content/gdrive', force_remount=True)

df = pd.read_csv (r'/content/gdrive/MyDrive/Colab Notebooks/Twitter_dataset.csv',encoding='latin1')

print (df)
# Out:
# Mounted at /content/gdrive
#       Unnamed: 0                       _id                      created_at  \
# 0              0  6020fc7e9e1aa8e3e7ad0832  Mon Feb 08 04:29:58 +0000 2021
# 1              1  6020fc7e9e1aa8e3e7ad0833  Mon Feb 08 04:29:55 +0000 2021
# 2              2  6020fc7e9e1aa8e3e7ad0834  Mon Feb 08 04:29:48 +0000 2021
# 3              3  6020fc7e9e1aa8e3e7ad0835  Mon Feb 08 04:29:43 +0000 2021
# 4              4  6020fc7e9e1aa8e3e7ad0836  Mon Feb 08 04:29:42 +0000 2021
# ...          ...                       ...                             ...
# 9751           3  6020fbb89e1aa8e3e7ac0a78  Mon Feb 08 02:01:58 +0000 2021
# 9752           4  6020fbb89e1aa8e3e7ac0a79  Mon Feb 08 01:00:24 +0000 2021
# 9753           5  6020fbb89e1aa8e3e7ac0a7a  Sun Feb 07 23:44:20 +0000 2021
# 9754           6  6020fbb89e1aa8e3e7ac0a7b  Sun Feb 07 23:33:40 +0000 2021
# 9755           7  6020fbb89e1aa8e3e7ac0a7c  Sun Feb 07 23:32:32 +0000 2021
#
# ...

# %%
#look at the top rows
df.head(10)
# Out:
#    Unnamed: 0                       _id                      created_at  \
# 0           0  6020fc7e9e1aa8e3e7ad0832  Mon Feb 08 04:29:58 +0000 2021
# 1           1  6020fc7e9e1aa8e3e7ad0833  Mon Feb 08 04:29:55 +0000 2021
# 2           2  6020fc7e9e1aa8e3e7ad0834  Mon Feb 08 04:29:48 +0000 2021
# 3           3  6020fc7e9e1aa8e3e7ad0835  Mon Feb 08 04:29:43 +0000 2021
# 4           4  6020fc7e9e1aa8e3e7ad0836  Mon Feb 08 04:29:42 +0000 2021
# 5           5  6020fc7e9e1aa8e3e7ad0837  Mon Feb 08 04:29:40 +0000 2021
# 6           6  6020fc7e9e1aa8e3e7ad0838  Mon Feb 08 04:29:40 +0000 2021
# 7           7  6020fc7e9e1aa8e3e7ad0839  Mon Feb 08 04:29:37 +0000 2021
# 8           8  6020fc7e9e1aa8e3e7ad083a  Mon Feb 08 04:29:36 +0000 2021
# 9           9  6020fc7e9e1aa8e3e7ad083b  Mon Feb 08 04:29:35 +0000 2021
#
#              id               id_str  \
# 0  1.358630e+18  1358634152719839233
# 1  1.358630e+18  1358634138639605762
# 2  1.358630e+18  1358634110600826880
# ...

# %%
#look at last rows
df.tail(10)
# Out:
#       Unnamed: 0                       _id                      created_at  \
# 9746         120  6020fbb69e1aa8e3e7ac0706  Sun Feb 07 23:34:29 +0000 2021
# 9747         121  6020fbb69e1aa8e3e7ac0707  Sun Feb 07 23:30:04 +0000 2021
# 9748           0  6020fbb89e1aa8e3e7ac0a75  Mon Feb 08 03:16:33 +0000 2021
# 9749           1  6020fbb89e1aa8e3e7ac0a76  Mon Feb 08 02:04:19 +0000 2021
# 9750           2  6020fbb89e1aa8e3e7ac0a77  Mon Feb 08 02:03:07 +0000 2021
# 9751           3  6020fbb89e1aa8e3e7ac0a78  Mon Feb 08 02:01:58 +0000 2021
# 9752           4  6020fbb89e1aa8e3e7ac0a79  Mon Feb 08 01:00:24 +0000 2021
# 9753           5  6020fbb89e1aa8e3e7ac0a7a  Sun Feb 07 23:44:20 +0000 2021
# 9754           6  6020fbb89e1aa8e3e7ac0a7b  Sun Feb 07 23:33:40 +0000 2021
# 9755           7  6020fbb89e1aa8e3e7ac0a7c  Sun Feb 07 23:32:32 +0000 2021
#
#                 id               id_str  \
# 9746  1.358560e+18  1358559791292047360
# 9747  1.358560e+18  1358558680879296512
# ...

# %%
#get a summary of the dataset
df.describe()
# Out:
#         Unnamed: 0            id        id_str  in_reply_to_status_id  \
# count  9756.000000  9.756000e+03  9.756000e+03           2.863000e+03
# mean   4749.132226  1.358590e+18  1.358590e+18           1.357976e+18
# std    2813.702919  2.346799e+13  2.281055e+13           1.813591e+16
# min       0.000000  1.358560e+18  1.358559e+18           4.475270e+17
# 25%    2308.750000  1.358570e+18  1.358567e+18           1.358560e+18
# 50%    4747.500000  1.358590e+18  1.358587e+18           1.358580e+18
# 75%    7186.250000  1.358610e+18  1.358610e+18           1.358600e+18
# max    9625.000000  1.358630e+18  1.358634e+18           1.358630e+18
#
#        in_reply_to_status_id_str  in_reply_to_user_id  \
# count               2.863000e+03         2.985000e+03
# mean                1.357976e+18         7.661037e+17
# std                 1.813591e+16         5.781080e+17
# min                 4.475267e+17         2.682300e+04
# 25%                 1.358558e+18         1.399829e+09
# ...

# %%
#look at the datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9756 entries, 0 to 9755
# Data columns (total 39 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 9756 non-null   int64
#  1   _id                        9756 non-null   object
#  2   created_at                 9756 non-null   object
#  3   id                         9756 non-null   float64
#  4   id_str                     9756 non-null   int64
#  5   text                       9756 non-null   object
#  6   display_text_range         3222 non-null   object
#  7   source                     9747 non-null   object
#  8   truncated                  9756 non-null   bool
#  9   in_reply_to_status_id      2863 non-null   float64
#  10  in_reply_to_status_id_str  2863 non-null   float64
#  11  in_reply_to_user_id        2985 non-null   float64
#  12  in_reply_to_user_id_str    2985 non-null   float64
# ...

# %% [markdown]
# ## Clean up the data
# Did you notice anything unusual about the "house" amounts?
#
# How about the handset price and income?

# %%
df_clean = df[(df['retweet_count'] > 0) & (df['reply_count'] > 0) & (df['favorite_count'] > 0) & (df['quote_count'] > 0)]
df_clean.describe()
# Out:
#         Unnamed: 0            id        id_str  in_reply_to_status_id  \
# count    54.000000  5.400000e+01  5.400000e+01           6.000000e+00
# mean   6246.685185  1.358578e+18  1.358580e+18           1.358570e+18
# std    2925.999128  2.408711e+13  2.307644e+13           2.000000e+13
# min     270.000000  1.358560e+18  1.358559e+18           1.358560e+18
# 25%    4118.250000  1.358560e+18  1.358563e+18           1.358560e+18
# 50%    7394.000000  1.358570e+18  1.358566e+18           1.358560e+18
# 75%    8387.500000  1.358590e+18  1.358594e+18           1.358568e+18
# max    9620.000000  1.358630e+18  1.358631e+18           1.358610e+18
#
#        in_reply_to_status_id_str  in_reply_to_user_id  \
# count               6.000000e+00         6.000000e+00
# mean                1.358570e+18         1.529387e+17
# std                 1.752875e+13         3.746217e+17
# min                 1.358558e+18         1.248058e+07
# 25%                 1.358563e+18         1.826906e+07
# ...

# %% [markdown]
# # Add Derived Attribute
#
# Add a column with the income in K (thousands)

# %%
df_clean = df[(df['retweet_count'] > 0)]
df_clean.describe()
# Out:
#         Unnamed: 0            id        id_str  in_reply_to_status_id  \
# count   383.000000  3.830000e+02  3.830000e+02           5.400000e+01
# mean   5345.496084  1.358584e+18  1.358586e+18           1.358569e+18
# std    3114.298045  2.480633e+13  2.370264e+13           7.353721e+13
# min       3.000000  1.358560e+18  1.358559e+18           1.358110e+18
# 25%    2166.500000  1.358560e+18  1.358564e+18           1.358560e+18
# 50%    5955.000000  1.358580e+18  1.358577e+18           1.358580e+18
# 75%    8315.000000  1.358610e+18  1.358609e+18           1.358600e+18
# max    9625.000000  1.358630e+18  1.358633e+18           1.358630e+18
#
#        in_reply_to_status_id_str  in_reply_to_user_id  \
# count               5.400000e+01         5.700000e+01
# mean                1.358569e+18         4.339799e+17
# std                 7.318377e+13         5.822058e+17
# min                 1.358113e+18         1.240514e+07
# 25%                 1.358563e+18         2.598640e+08
# ...

# %% [markdown]
# ## Slice the data
#  What is average house price at the two levels of leave?
#
#  Conclusion?  Stayers have substantially more expensive homes.

# %%
df_clean[['house','leave']].groupby('leave').mean().round(2)

# %%
df.isna().sum()
# Out:
# Unnamed: 0                      0
# _id                             0
# created_at                      0
# id                              0
# id_str                          0
# text                            0
# display_text_range           6534
# source                          9
# truncated                       0
# in_reply_to_status_id        6893
# in_reply_to_status_id_str    6893
# in_reply_to_user_id          6771
# in_reply_to_user_id_str      6771
# in_reply_to_screen_name      6771
# user                            0
# geo                          9753
# coordinates                  9753
# place                        9616
# contributors                 9756
# is_quote_status                 0
# quote_count                     0
# reply_count                     0
# retweet_count                   0
# favorite_count                  0
# entities                        0
# favorited                       0
# retweeted                       0
# ...

# %%
df_clean = df.dropna(0)
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 39 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 0 non-null      int64
#  1   _id                        0 non-null      object
#  2   created_at                 0 non-null      object
#  3   id                         0 non-null      float64
#  4   id_str                     0 non-null      int64
#  5   text                       0 non-null      object
#  6   display_text_range         0 non-null      object
#  7   source                     0 non-null      object
#  8   truncated                  0 non-null      bool
#  9   in_reply_to_status_id      0 non-null      float64
#  10  in_reply_to_status_id_str  0 non-null      float64
#  11  in_reply_to_user_id        0 non-null      float64
#  12  in_reply_to_user_id_str    0 non-null      float64
# ...

# %%
df['favorite_count'].plot.line(color='purple', figsize=(11,4))

# %%
df['lang'].value_counts()
# Out:
# en     3971
# ja     2402
# th     1768
# und     439
# hi      313
# es      214
# pt      130
# ko      121
# in       95
# ht       52
# fr       49
# tr       38
# et       20
# ar       18
# tl       15
# zh       14
# de       10
# eu        9
# it        8
# sv        7
# mr        7
# da        7
# ne        6
# ur        5
# iw        5
# nl        4
# no        4
# hu        3
# fa        3
# lv        2
# pl        2
# ru        2
# lt        2
# bn        2
# fi        2
# gu        2
# cs        2
# vi        1
# ca        1
# uk        1
# Name: lang, dtype: int64
